# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # not weighted deep walk

# %%
from graph_pkg import run_deepwalk
from graph_pkg import run_tsne
from graph_pkg import plot_tsne
import numpy  as np
import pandas as pd

data_dir = "/data/deyk/fabiha/20231112_dingyu"
scripts_dir = "/lila/home/fabihat/msk_labwork/20231112_dingyu"

#name = 'd3_ko_deg_padj05'
#name = 'd3_de1_ko_deg_padj05'
#name = 'd3_de2_ko_deg_padj05'

#name = 'd7_ko_deg_padj05'
#name = 'd7_liver_ko_deg_padj05'
#name = 'd7_pfg1_ko_deg_padj05'
#name = 'd7_pfg2_ko_deg_padj05'

#name = 'd11_ko_deg_padj05'
#name = 'd11_ep_ko_deg_padj05'
#name = 'd11_pp1_ko_deg_padj05'
#name = 'd11_pp2_ko_deg_padj05'

name = 'd18_ko_deg_padj05'
#name = 'd18_endo_ko_deg_padj05'
#name = 'd18_ep_ko_deg_padj05'
#name = 'd18_none_ko_deg_padj05'
#name = 'd18_scalpha_ko_deg_padj05'
#name = 'd18_scbeta_ko_deg_padj05'
#name = 'd18_scdelta_ko_deg_padj05'
#name = 'd18_scec_ko_deg_padj05'
#name = 'd18_stromal_ko_deg_padj05'
#name = 'd18_unk_ko_deg_padj05'

#name = 'd3_combined_celltypes_sameKO'
#name = 'd7_combined_celltypes_sameKO'
#name = 'd11_combined_celltypes_sameKO'
#name = 'd18_combined_celltypes_sameKO'

#name = 'd3_combined_celltypes_diffKO'
#name = 'd7_combined_celltypes_diffKO'
#name = 'd11_combined_celltypes_diffKO'
#name = 'd18_combined_celltypes_diffKO'

#name = 'd18_priority_combined_celltypes_weights'

## run deepwalk weighted
read_graphml = f"{data_dir}/{name}.graphml"
name += "_deepwalk_noweight"

write_log = f"{scripts_dir}/{name}.log"
write_embedding = f"{data_dir}/{name}_embeddings.npy"
write_model = f"{data_dir}/{name}_embeddings.model"

run_deepwalk.deepwalk(read_graphml, write_log, write_embedding, write_model)

## rewrite embedding file
read_embedding = write_embedding
write_embedding_tsv = f"{data_dir}/{name}_embeddings.tsv"

embeddings = np.load(read_embedding, allow_pickle=True)
embeddings = embeddings.item()
embeddings = pd.DataFrame.from_dict(embeddings, orient="index")
embeddings = embeddings.reset_index().rename(columns={"index":"labels"})
embeddings.to_csv(write_embedding_tsv, index=False, header=False, sep="\t")

## run tsne
read_embedding_tsv = write_embedding_tsv
write_tsne = f"{data_dir}/{name}_tsne_results.csv"

run_tsne.tsne(read_embedding_tsv, write_log, write_tsne)

## plot tsne
read_tsne = write_tsne
write_png = f"{scripts_dir}/{name}_tsne_plot.png"

plot_tsne.plot_tsne(read_tsne, write_log, write_png)

# %% [markdown]
# # not weighted deep walk programs v2

# %%
from graph_pkg import run_deepwalk_programsv2
from graph_pkg import run_tsne
from graph_pkg import plot_tsne
import numpy  as np
import pandas as pd

data_dir = "/data/deyk/fabiha/20231112_dingyu"
scripts_dir = "/lila/home/fabihat/msk_labwork/20231112_dingyu"

name = 'd3_ko_deg_padj05_programs'

## run deepwalk weighted
read_graphml = f"{data_dir}/{name}.graphml"
name += "_deepwalk_noweight_programsv2"

write_log = f"{scripts_dir}/{name}.log"
write_embedding = f"{data_dir}/{name}_embeddings.npy"
write_model = f"{data_dir}/{name}_embeddings.model"

run_deepwalk_programsv2.deepwalk(read_graphml, write_log, write_embedding, write_model)

## rewrite embedding file
read_embedding = write_embedding
write_embedding_tsv = f"{data_dir}/{name}_embeddings.tsv"

embeddings = np.load(read_embedding, allow_pickle=True)
embeddings = embeddings.item()
embeddings = pd.DataFrame.from_dict(embeddings, orient="index")
embeddings = embeddings.reset_index().rename(columns={"index":"labels"})
embeddings.to_csv(write_embedding_tsv, index=False, header=False, sep="\t")

## run tsne
read_embedding_tsv = write_embedding_tsv
write_tsne = f"{data_dir}/{name}_tsne_results.csv"

run_tsne.tsne(read_embedding_tsv, write_log, write_tsne)

## plot tsne
read_tsne = write_tsne
write_png = f"{scripts_dir}/{name}_tsne_plot.png"

plot_tsne.plot_tsne(read_tsne, write_log, write_png)

# %% [markdown]
# # deep walk programs w celltype weights

# %% [markdown]
# ## tsne

# %%
#from graph_pkg import run_deepwalk
from graph_pkg import run_deepwalk_programs_celltype_weights_combined
from graph_pkg import run_tsne
from graph_pkg import plot_tsne
import numpy  as np
import pandas as pd

data_dir = "/data/deyk/fabiha/20231112_dingyu"
scripts_dir = "/lila/home/fabihat/msk_labwork/20231112_dingyu"

name = 'd18_priority_combined_celltypes_weights'
#name = 'd18_priority_top_combined_celltypes_weights'

## run deepwalk weighted
read_graphml = f"{data_dir}/{name}.graphml"
read_idx = f"{data_dir}/{name}_toidx.npy"

#name += "_deepwalk_noweight"
#name += "_deepwalk_programs_celltype_weights"
#name += "_deepwalk_programs_celltype_weights_combined"

write_log = f"{scripts_dir}/{name}.log"
write_embedding = f"{data_dir}/{name}_embeddings.npy"
write_model = f"{data_dir}/{name}_embeddings.model"

run_deepwalk_programs_celltype_weights_combined.deepwalk(read_graphml, write_log, write_embedding, write_model)

## rewrite embedding file
read_embedding = write_embedding
write_embedding_tsv = f"{data_dir}/{name}_embeddings.tsv"

embeddings = np.load(read_embedding, allow_pickle=True)
embeddings = embeddings.item()
embeddings = pd.DataFrame.from_dict(embeddings, orient="index")
embeddings = embeddings.reset_index().rename(columns={"index":"labels"})
embeddings.to_csv(write_embedding_tsv, index=False, header=False, sep="\t")

## run tsne
read_embedding_tsv = write_embedding_tsv
write_tsne = f"{data_dir}/{name}_tsne_results.csv"

run_tsne.tsne(read_embedding_tsv, write_log, write_tsne)

## plot tsne
read_tsne = write_tsne
write_png = f"{scripts_dir}/{name}_tsne_plot.png"

plot_tsne.plot_tsne(read_tsne, write_log, write_png)

# %% [markdown]
# ## pca

# %%
#from graph_pkg import run_deepwalk
from graph_pkg import run_deepwalk_programs_celltype_weights_combined
from graph_pkg import run_pca
from graph_pkg import plot_pca
import numpy  as np
import pandas as pd

data_dir = "/data/deyk/fabiha/20231112_dingyu"
scripts_dir = "/lila/home/fabihat/msk_labwork/20231112_dingyu"

#name = 'd18_priority_combined_celltypes_weights'
name = 'd18_priority_top_combined_celltypes_weights'

## run deepwalk weighted
read_graphml = f"{data_dir}/{name}.graphml"
read_idx = f"{data_dir}/{name}_toidx.npy"

#name += "_deepwalk_noweight"
#name += "_deepwalk_programs_celltype_weights"
name += "_deepwalk_programs_celltype_weights_combined"

write_log = f"{scripts_dir}/{name}.log"
write_embedding = f"{data_dir}/{name}_embeddings.npy"
write_model = f"{data_dir}/{name}_embeddings.model"

run_deepwalk_programs_celltype_weights_combined.deepwalk(read_graphml, write_log, write_embedding, write_model)

## rewrite embedding file
read_embedding = write_embedding
write_embedding_tsv = f"{data_dir}/{name}_embeddings.tsv"

embeddings = np.load(read_embedding, allow_pickle=True)
embeddings = embeddings.item()
embeddings = pd.DataFrame.from_dict(embeddings, orient="index")
embeddings = embeddings.reset_index().rename(columns={"index":"labels"})
embeddings.to_csv(write_embedding_tsv, index=False, header=False, sep="\t")

## run pca
read_embedding_tsv = write_embedding_tsv
write_tsne = f"{data_dir}/{name}_pca_results.csv"

run_pca.pca(read_embedding_tsv, write_log, write_tsne)

## plot pca
#read_tsne = write_tsne
#write_png = f"{scripts_dir}/{name}_pca_plot.png"

#plot_pca.plot_pca(read_tsne, write_log, write_png)

# %% [markdown]
# # deep walk programs w weights

# %% [markdown]
# ## tsne

# %%
from graph_pkg import run_deepwalk_programs_celltype_weights_frankenstein
from graph_pkg import run_tsne
from graph_pkg import plot_tsne
import numpy  as np
import pandas as pd

data_dir = "/data/deyk/fabiha/20231112_dingyu"
scripts_dir = "/lila/home/fabihat/msk_labwork/20231112_dingyu"

#name = 'd3_ko_deg_padj05'

#name = 'd18_ko_deg_padj05'

#name = 'd18_combined_celltypes_sameKO'
#name = 'd18_priority_combined_celltypes_sameKO'

name = 'd18_priority_combined_celltypes_weights'
#name = 'd18_priority_top_combined_celltypes_weights'

programs_path = "/lila/data/deyk/fabiha/20231112_dingyu/data/D18_sample_L_celltype_programs.txt"
#programs_path = "/lila/data/deyk/fabiha/20231112_dingyu/data/D18_sample_L_celltype_all_programs.txt"

weights_path = "/lila/data/deyk/fabiha/20231112_dingyu/d18_cell_composition.csv"

## run deepwalk weighted
read_graphml = f"{data_dir}/{name}.graphml"
read_idx = f"{data_dir}/{name}_toidx.npy"
#name += "_deepwalk_noweight_programs_weights"
#name += "_deepwalk_noweight_programs_weightsv2"
#name += "_deepwalk_noweight_programs_weightsv3"
#name += "_deepwalk_noweight_programs_weightsv4"
#name += "_deepwalk_noweight_programs_weightsv5"
#name += "_deepwalk_noweight_programs_weightsv7"

#name += "_deepwalk_noweight_programs_weightsv6"

name += "_deepwalk_programs_celltype_weights_frankenstein"

write_log = f"{scripts_dir}/{name}.log"
write_embedding = f"{data_dir}/{name}_embeddings.npy"
write_model = f"{data_dir}/{name}_embeddings.model"

run_deepwalk_programs_celltype_weights_frankenstein.deepwalk(read_graphml, read_idx, programs_path, weights_path, write_log, write_embedding, write_model)

## rewrite embedding file
read_embedding = write_embedding
write_embedding_tsv = f"{data_dir}/{name}_embeddings.tsv"

embeddings = np.load(read_embedding, allow_pickle=True)
embeddings = embeddings.item()
embeddings = pd.DataFrame.from_dict(embeddings, orient="index")
embeddings = embeddings.reset_index().rename(columns={"index":"labels"})
embeddings.to_csv(write_embedding_tsv, index=False, header=False, sep="\t")

## run tsne
read_embedding_tsv = write_embedding_tsv
write_tsne = f"{data_dir}/{name}_tsne_results.csv"

run_tsne.tsne(read_embedding_tsv, write_log, write_tsne)

## plot tsne
read_tsne = write_tsne
write_png = f"{scripts_dir}/{name}_tsne_plot.png"

plot_tsne.plot_tsne(read_tsne, write_log, write_png)

# %% [markdown]
# # not weighted deep walk programs

# %% [markdown]
# ### just plot

# %%
from graph_pkg import plot_tsne

data_dir = "/data/deyk/fabiha/20231112_dingyu"
scripts_dir = "/lila/home/fabihat/msk_labwork/20231112_dingyu"

name = 'd3_ko_deg_padj05'

## run deepwalk weighted
read_graphml = f"{data_dir}/{name}.graphml"
name += "_deepwalk_noweight"

## plot tsne
read_tsne = f"{data_dir}/{name}_tsne_results.csv"
write_log = f"{scripts_dir}/{name}.log"
write_png = f"{scripts_dir}/{name}_tsne_plot.png"

plot_tsne.plot_tsne(read_tsne, write_log, write_png)

# %% [markdown]
# ### model

# %%
from graph_pkg import run_deepwalk_programs
from graph_pkg import run_tsne
from graph_pkg import plot_tsne
import numpy  as np
import pandas as pd

data_dir = "/data/deyk/fabiha/20231112_dingyu"
scripts_dir = "/lila/home/fabihat/msk_labwork/20231112_dingyu"

name = 'd3_ko_deg_padj05'

programs_path = "/lila/data/deyk/fabiha/20231112_dingyu/data/D3_sample_H_celltype_programs.txt"

## run deepwalk weighted
read_graphml = f"{data_dir}/{name}.graphml"
read_idx = f"{data_dir}/{name}_toidx.npy"
name += "_deepwalk_noweight_programs"

write_log = f"{scripts_dir}/{name}.log"
write_embedding = f"{data_dir}/{name}_embeddings.npy"
write_model = f"{data_dir}/{name}_embeddings.model"

run_deepwalk_programs.deepwalk(read_graphml, read_idx, programs_path, write_log, write_embedding, write_model)

## rewrite embedding file
read_embedding = write_embedding
write_embedding_tsv = f"{data_dir}/{name}_embeddings.tsv"

embeddings = np.load(read_embedding, allow_pickle=True)
embeddings = embeddings.item()
embeddings = pd.DataFrame.from_dict(embeddings, orient="index")
embeddings = embeddings.reset_index().rename(columns={"index":"labels"})
embeddings.to_csv(write_embedding_tsv, index=False, header=False, sep="\t")

## run tsne
read_embedding_tsv = write_embedding_tsv
write_tsne = f"{data_dir}/{name}_tsne_results.csv"

run_tsne.tsne(read_embedding_tsv, write_log, write_tsne)

## plot tsne
read_tsne = write_tsne
write_png = f"{scripts_dir}/{name}_tsne_plot.png"

plot_tsne.plot_tsne(read_tsne, write_log, write_png)
